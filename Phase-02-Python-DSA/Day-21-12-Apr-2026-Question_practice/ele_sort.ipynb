# %%
'''
check if array is sorted or not
'''

# %%
nums = [56, 23, 89, 45, 12, 78]
n=len(nums)
for i in range(0,n-1):
    if nums[i]>nums[i+1]:
        print("Array is not sorted")
        break
else:
    print("Array is sorted")
# Out:
# Array is not sorted
