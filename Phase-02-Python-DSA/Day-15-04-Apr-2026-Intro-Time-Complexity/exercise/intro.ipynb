# %%
''' 
What is efficiency in programming?

Efficiency in programming refers to how well a program utilizes resources such as time and memory to perform its tasks.
An efficient program runs faster and uses less memory, which can lead to better performance and user experience.
Efficiency can be measured in terms of time complexity (how the execution time of an algorithm changes with the size of the input) and space complexity (how the memory usage of an algorithm changes with the size of the input).


'''

# %%
'''
DATA STRUCTURES AND ALGORITHMS 

Data Structures and Algorithms (DSA) are fundamental concepts in computer science that help in organizing and processing data efficiently.
Data Structures are ways of organizing and storing data in a computer so that it can be accessed and modified efficiently. 
Examples include arrays, linked lists, stacks, queues, trees, and graphs.

Algorithms are step-by-step procedures or formulas for solving problems. They are a set of instructions that take an input and produce an output.
Examples include sorting algorithms (like bubble sort, merge sort), searching algorithms (like binary search),
and graph algorithms (like Dijkstra's algorithm).

'''

# %%
''' 
Why it is important  ?
for time efficiency, 
lets take a example of google when we search something on google it gives us the result in fraction of seconds, this is possible because of efficient algorithms and data structures that google uses to process and retrieve data quickly.

for space efficiency,
lets take an example of a mobile phone, mobile phones have limited storage capacity, so it is important for apps to be efficient in their use of memory.
An app that uses too much memory can slow down the phone and drain the battery quickly. 
Efficiency in both time and space is crucial for developing high-performing applications.

'''
