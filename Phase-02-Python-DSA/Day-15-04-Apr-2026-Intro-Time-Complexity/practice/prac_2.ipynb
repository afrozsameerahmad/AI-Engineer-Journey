# %%
l=[1, 2, 3, 4, 5]
for i in l:
    for j in l:
        print('{}, {}'.format(i, j))
# Out:
# 1, 1
# 1, 2
# 1, 3
# 1, 4
# 1, 5
# 2, 1
# 2, 2
# 2, 3
# 2, 4
# 2, 5
# 3, 1
# 3, 2
# 3, 3
# 3, 4
# 3, 5
# 4, 1
# 4, 2
# 4, 3
# 4, 4
# 4, 5
# 5, 1
# 5, 2
# 5, 3
# 5, 4
# 5, 5

# %%
# time complexity of above code is O(n^2) because we have two nested loops and each loop runs n times where n is the size of the input list l.
