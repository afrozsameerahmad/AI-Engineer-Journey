# %%
'''
Input:

arr = [1,2,2,3,4,4]

Output:

4
'''

# %%
arr = [1,2,2,3,4,4]
distinct = set(arr)
print(len(distinct))
# Out:
# 4

# %%
#using hash map
freq = {}
for i in arr:
    freq[i] = freq.get(i, 0) + 1
print(len(freq))
# Out:
# 4
