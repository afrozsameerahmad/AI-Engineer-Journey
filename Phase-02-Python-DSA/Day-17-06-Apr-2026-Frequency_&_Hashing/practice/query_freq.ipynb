# %%
''' 
Given:
arr = [1,2,2,3,3,3]
queries = [1,2,4]

output :
[1,2,0]

'''

# %%
arr = [1,2,2,3,3,3]
queries = [1,2,4]
hash_map={}
for i in arr:
    hash_map[i]=hash_map.get(i,0)+1
result = []
for i in queries:
     result.append(hash_map.get(i,0))
print(result)
# Out:
# [1, 2, 0]
