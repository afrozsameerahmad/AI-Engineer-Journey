# %%
'''
Space Complexity
space complexity is the amount of memory used by an algorithm as a function of the input size. 
It is often expressed using Big O notation, which describes the upper bound of the growth rate of the space used by the algorithm.

Auxilary Space Complexity
Auxiliary space complexity refers to the extra space or temporary space used by an algorithm, excluding the space used by the input data. 
It is also expressed using Big O notation and is often used to analyze the efficiency of an algorithm in terms of its memory usage.

input space complexity is the space required to store the input data,
while auxiliary space complexity is the additional space required by the algorithm to perform its operations.

example :
x=10 
y=5
z=3
total = x + y + z
in this above example 
x,y,z are the input space complexity 
total is the auxiliary space complexity

'''

# %%
''' 
TLE=Time limit error
whenever we write a code and it is taking more time than expected to execute, we get TLE error.

'''
