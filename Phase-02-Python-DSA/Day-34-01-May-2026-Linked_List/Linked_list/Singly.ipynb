# %%
'''
Singly Linked list is defined as a data structure 
that consists of a sequence of nodes,
where each node contains data and a reference (or link) to the next node in the sequence.
The last node in the list points to null, indicating the end of the list.
Singly linked lists are commonly used for dynamic memory allocation and efficient insertion and deletion operations.

'''

# %%
class Node:
    def __init__(self, val):
        self.val = val
        self.next = None


class SinglyLinkedList:
    def __init__(self):
        self.head = None

    def insert_at_end(self, val):
        new_node = Node(val)
        if self.head is None:
            self.head = new_node
        else:
            curr = self.head
            while curr.next is not None:
                curr = curr.next
            curr.next = new_node

    def traverse(self):
        if not self.head:
            print("SLL IS EMPTY")
        else:
            curr = self.head
            while curr is not None:
                print(curr.val, end=" ")
                curr = curr.next
            print()

    def insert_at_specified_position(self, val, pos):
        new_node = Node(val)
        if pos == 0:
            new_node.next = self.head
            self.head = new_node
        else:
            curr = self.head
            count = 0
            while curr is not None and count < pos - 1:
                curr = curr.next
                count += 1

            if curr is None:
                print("Position out of bounds")
            else:
                new_node.next = curr.next
                curr.next = new_node

    def delete(self, val):
        temp = self.head

        if temp is None:
            print("List is empty")
            return

        if temp.val == val:
            self.head = temp.next
            return

        prev = None
        while temp is not None:
            if temp.val == val:
                break
            prev = temp
            temp = temp.next

        if temp is not None:
            prev.next = temp.next
        else:
            print("Value not found")


sll = SinglyLinkedList()
sll.insert_at_end(10)
sll.insert_at_end(20)
sll.insert_at_end(30)

sll.traverse()

sll.insert_at_specified_position(15, 1)
sll.traverse()

sll.delete(20)
sll.traverse()
# Out:
# 10 20 30
# 10 15 20 30
# 10 15 30
