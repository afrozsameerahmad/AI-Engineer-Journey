# %% [markdown]
# ### Some Theory
#
# ##### Types of data used for I/O:
# - Text - '12345' as a sequence of unicode chars
# - Binary - 12345 as a sequence of bytes of its binary equivalent
#
# ##### Hence there are 2 file types to deal with
# - Text files - All program files are text files
# - Binary Files - Images,music,video,exe files

# %% [markdown]
# ### How File I/O is done in most programming languages
#
# - Open a file
# - Read/Write data
# - Close the file

# %%
# Writing a file

#case 1 if the file is not present

f =open("sample.txt",'w')
f.write("this is sample text")
f.close()
# f.write("this is sample text") 
# this will give error because file is closed

# %%
#write multiple lines in file
f=open("sample.txt",'w')
f.write("hello world")
f.write("\n welcome to python")
f.close()

# %%
# case 2 if the file is already present

f=open("sample.txt",'w')
f.write("Sameer Ahmad")
f.close()

# %%
# how exactly open() works
''' 
this sample.txt file is inside hard drive  
,rom me hai to ram me lana padega to open() function is used to load the file in ram and then we can perform operations on it and then we can save it back to hard drive by using close() function
basically open() function is used to load the file in ram and buffer memory and then only we can
perform oprations and after close() function the buffer memory is cleared and the file again saved in hard drive

in buffer memory our file read char by char 

'''

# %%
# Problem with w mode in write when we do operations the existing data will lost
# Introducing append mode

f = open("sample.txt",'a')
f.write("\n this is append mode")
f.close()
'''
#close() function is used to save the file in hard drive and clear the buffer memory 
# why we close the file because if we do not close the file then the data will not be saved in hard drive 
# and also the buffer memory will not be cleared and it will create problem in future when we will try to open the file again
# because the buffer memory will be full and it will create problem in opening the file again 
# and also if our device hacked then the hacker can access our buffer memory and can steal our data so
# it is always recommended to close the file after performing operations on it  '''
# Out:
# '\n#close() function is used to save the file in hard drive and clear the buffer memory \n# why we close the file because if we do not close the file then the data will not be saved in hard drive \n# and also the buffer memory will not be cleared and it will create problem in future when we will try to open the file again\n# because the buffer memory will be full and it will create problem in opening the file again \n# and also if our device hacked then the hacker can access our buffer memory and can steal our data so\n# it is always recommended to close the file after performing operations on it  '

# %%
# Write lines 
l=["hello hi how are you \n ","i am fine thank you \n","what about you \n"]
f = open("sample.txt",'w')
f.writelines(l)
f.close()

# %%
# read mode - reading a file
# using read() method
f=open("sample.text",'r')
s=f.read()
print(s)
f.close()
# Out:
# hello hi how are you
#  i am fine thank you
# what about you

# %%
# reading upto n chars
f=open("sample.txt",'r')
s=f.read(10)
print(s)
f.close()
# Out:
# hello hi h

# %%
# realline() read line by line
f=open("sample.text",'r')
print(f.readline(),end='')
print(f.readline(),end='')
f.close()
# Out:
# hello hi how are you
#  i am fine thank you

# %%
# reading entire using readline
f= open('sample.txt','r')
while True:
    data = f.readline()
    if data == '':
        break
    else:
        print(data,end='')
f.close()
# Out:
# hello hi how are you
#  i am fine thank you
# what about you

# %% [markdown]
# ### Using Context Manager (With)
#
# - It's a good idea to close a file after usage as it will free up the resources
# - If we dont close it, garbage collector would close it
# - with keyword closes the file as soon as the usage is over

# %%
# with
with open("sample.txt",'w') as f:
    f.write("this is with statement")

# %%
with open("sample.txt",'r') as f:
    data = f.read()
    print(data)
# Out:
# this is with statement

# %%
# moving within a file --> 10 char then 10 char
with open("sample.txt",'r') as f:
    print(f.read(10))
    print(f.read(10))
# Out:
# this is wi
# th stateme

# %%
# benefit ? to load a big file in memory

big_L=["Sameer Ahmad \n" for i in range(1000)]
with open("big_file.txt",'w')as f:
    f.writelines(big_L)

# %%
with open("big_file.txt",'r') as f:
    chunk_size = 5
    
    while len(f.read(chunk_size)) > 0:
        print(f.read(chunk_size), end='')
        f.read(chunk_size)

# %%
# seek and tell  function
#seek() function is used to move the file pointer to a specific position in the file 
# tell() function is used to get the current position of the file pointer

with open("sample.txt",'r') as f:
    print(f.read(10))
 
    print(f.tell())
    f.seek(15)
    print(f.read(10))
# Out:
# this is wi
# 10
# atement

# %%
#seek during write
with open("sample.txt",'w') as f:
    f.write("hello world")
    f.seek(0)
    f.write("hi everyone")

# %% [markdown]
# ### Problems with working in text mode
#
# - can't work with binary files like images
# - not good for other data types like int/float/list/tuples

# %%
#working with binary file
with open("profile.jpeg",'rb') as f:
    with open("copy_profile.jpeg",'wb') as f1:
        f1.write(f.read())
