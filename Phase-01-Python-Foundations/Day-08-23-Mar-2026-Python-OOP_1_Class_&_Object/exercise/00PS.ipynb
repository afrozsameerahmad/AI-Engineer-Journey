# %%
#this topic is for objects and classes so all recommendation give according to this topic.
''' 

Everthing in python is an object, including functions,datatypes and all other entities.

Object are defined as an instance of a class. A class is a blueprint for creating objects, 
and it defines the properties and behaviors of those objects.

The main power of OOP is that it allows us to create our own data types and objects. 
We can define our own classes and create instances of those classes, which are called objects. 
This allows us to model real-world entities and their behaviors in our code.

'''


'''
Objects oriented programming (OOP) is a programming paradigm that is based on the concept of objects.
-OBJECTS: Objects are instances of classes that encapsulate data and behavior. They can represent real-world entities or abstract concepts.

-CLASSES: Classes are blueprints for creating objects. They define the properties (attributes) and behaviors (methods)
that the objects of that class will have.

-ENCAPSULATION: Encapsulation is the principle of bundling data and methods that operate on that data within a single unit (class). 
It helps to hide the internal details of an object and only expose a public interface.

-INHERITANCE: Inheritance is a mechanism that allows a new class (called a subclass or child class) to inherit properties and behaviors from an existing class (called a superclass or parent class). 
This promotes code reusability and allows for the creation of a hierarchical class structure.

-POLYMORPHISM: Polymorphism is the ability of different classes to be treated as instances of the same class through a common interface.
It allows for the use of a single interface to represent different types of objects, enabling flexibility and extensibility in code design.

-ABSTRACTION: Abstraction is the process of hiding the complex implementation details of an object and exposing only the necessary features.
It allows developers to focus on the essential aspects of an object while ignoring the irrelevant details. 


'''

# %%
L=[1,2,3,4,5]   
print(type(L))
# Out:
# <class 'list'>

# %%
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
# 'list' object has no attribute 'upper'


''' 

All data types in python are actually classes and all the values of those data types are objects of those classes.
in simple words when we create a variable and assign a value to it, we are actually creating an object of a class.

in above  code L is a list object and it is an instance of the list class.


'''
# Out:
# ' \n\nAll data types in python are actually classes and all the values of those data types are objects of those classes.\n\nin above  code L is a list object and it is an instance of the list class.\n\n\n'

# %%
'''

-----------Class-----

Class is a blueprint for creating objects. It defines the properties and behaviors of those objects.
A class is defined using the class keyword, followed by the name of the class and a colon   

example:car is a class and it defines the properties of a car such as color, model, year, etc. and behaviors such as start, stop, accelerate, etc.


Class is set of rules and object follows those rules.


Class have two main components:
1. Data or properties: These are the attributes that define the state of an object. For example, in a car class, 
the properties could be color, model, year, etc.

2. Functions or behaviors: These are the methods that define the actions that an object can perform.
For example, in a car class, the behaviors could be start, stop, accelerate, etc.



Class  basic structure:

class Car:
color = "red"  # data or properties
model= "sedan"  # data or properties
def calculate_avg_speed(km,time):  # function or behavior
    print("Calculating average speed...")
     
'''

# %%
# syntax to create an object of a class:

#object_name = ClassName()

#object literal syntax:
#object_name = ClassName(arguments)
l=[1,2,3,4,5]  # this is an object of list class and it is created using object literal syntax.
print(type(l))  # <class 'list'>
