# %%
'''  

-----Self -----

Golden Rule of OOP: 

Class and  objects

Class ke andr ham sare rules bnate hai jinko object follow krta hai.
Rules me ham 2 cheeze bnate hai jaise attributes and methods.

Golden Rule of OOP: 
aapke class ke jo members hai in dono ko sirf kaun access kr skta hai the answer is us class ka object.

"Everything in OOP is an object"
"object can access anything that is defined in the class"



Self is a reference to the current instance of the class.
It is used to access the attributes and methods of the class in Python.
When we define a method in a class, we need to include self as the first parameter.
This allows us to access the instance variables and other methods of the class using self.
When we create an object of the class and call a method, Python automatically passes the object as the first argument to the method, which is why we use self to refer to that object within the method.


'''

# %%
'''  
After knowing about self from previous cell 

one method cannot call the other method  answer is no.. because they are both independent of each other and they are not connected in any way.
example : in atm.pynb file we have  methods  lets take two methods check balance and withdraw money.
check balance method cannot call withdraw money method because they are both independent of each other and they are not connected in any way.

and this is the reason why we use self because self allows us to access the attributes and methods of the class in Python and it also allows us to call one method from another method within the same class.

in simple ek method ko dusre method ke andr call krne ke liye self ka use krte hai.


'''

# %%
class Temp:
    def __init__(self):
        print(id(self))
        print("Hello")
        
obj = Temp()
# Out:
# 2926523337104
# Hello

# %%
print(id(obj))
# Out:
# 2926523337104

# %%
#same id print hoga because self is a reference to the current instance of the class and obj is the current instance of the class Temp.

# constructor class ke object ko bolega and then class ka object method ko bolega 
# esme constructor __init__ method hai jo class ke object self ko bolega and then class ka object obj self ko bolega and then class ka object obj method ko bolega.
