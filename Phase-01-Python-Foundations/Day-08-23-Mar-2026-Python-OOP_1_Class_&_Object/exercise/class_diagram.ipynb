# %%
'''
# In ATM we have 3 attributes: pin, balance and account number. 
# We have 3 methods: check balance, withdraw money and deposit money.
# Each method will ask the user to enter their pin before performing the respective action.
# If the pin is correct, the action will be performed; otherwise, an error message will be displayed.

+ public means that the attribute or method can be accessed from outside the class.
- private means that the attribute or method cannot be accessed from outside the class.
It can only be accessed from within the class.
'''
# Out:
# '\n# In ATM we have 3 attributes: pin, balance and account number. \n# We have 3 methods: check balance, withdraw money and deposit money.\n# Each method will ask the user to enter their pin before performing the respective action.\n# If the pin is correct, the action will be performed; otherwise, an error message will be displayed.\n\n+ public means that the attribute or method can be accessed from outside the class.\n- private means that the attribute or method cannot be accessed from outside the class.\nIt can only be accessed from within the class.\n'
