# %%
''' 

---Magic Methods in Python aka Dunder Methods  The constructor __init__---

-Magic Methods in Python are special methods that have double underscores at the beginning and end of their names. 
-They are also known as dunder methods (short for "double underscore"). 
-These methods are used to define the behavior of objects in Python and are automatically called by Python when certain operations are performed on objects.
-For example, the __init__ method is a magic method that is called when an object is created. 
-It is used to initialize the attributes of the object. 
-The __str__ method is another magic method that is called when the str() function is used on an object. 
-It is used to define the string representation of the object.           



'''
