# %%
''' 
how function execute in memmory?

example

def is_even(num):
    if num%2==0:
        return 'even'
    else:
        return 'odd'
print(is_even(7))

jaise hi python ke interpreter ko def keyword dikhta hai o smjh jata h ki yha ek fun likha hua h 
then pure fun ko jump marke aage chla jata h print(is_even(7)) pr

after this jaise hi function call hoga ye waps def pe chla jaega 
aese hone pe ek seprate block bn jata a memory me 

jo fun hota hai o memory me ek chhote program ki trh behave krta hai independent program ki trh 

aur jaise hi function ka kaam khtm hota blocks apne aap destroy ho jaenge aur var bhi hoajenge 

if someone ask you whats the lifetime of funtion?

jab o call hota h aur jab o return marta hai tabtak esi ke bich me active rhega 


# without return statement funtion return krta h None by default


'''

# %%
l = [1,2,3]
print(l.append(4))
print(l)
# Out:
# None
# [1, 2, 3, 4]

# %%
'''
Variable Scope

Variable scope is the region of a program where a variable is defined and can be accessed. In Python, there are four types of variable scopes:

Those variable come under main program scope we call them global variable

and those variable comes under function scope we call them local variable

if inside function there is no variable then we can use global variable but we cannot change it 
but if we want to change we need global keyword 
example global x

'''

# %%
def g(y):
    print(x)
    print(x+1)
x=10
g(x)
print(x)
# Out:
# 10
# 11
# 10

# %%
def f(x):
    x=x+1
    print('in f(x) : x =',x)
    return x
x=3
z=f(x)
print('in main program scope : x =',x)
print('in main program scope : z =',z)
# Out:
# in f(x) : x = 4
# in main program scope : x = 3
# in main program scope : z = 4

# %% [markdown]
# #  NESTED FUNCTIONS

# %%
def f():
    def g():
        print('inside g()')
    g()
    print('inside f()')
f()
# Out:
# inside g()
# inside f()
