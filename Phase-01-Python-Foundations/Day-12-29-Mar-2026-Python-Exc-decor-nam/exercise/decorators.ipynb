# %% [markdown]
# ### Decorators
#
# A decorator in python is a function that receives another function as input and adds some functionality(decoration) to and it and returns it.
#
# This can happen only because python functions are 1st class citizens.
#
# There are 2 types of decorators available in python
# - `Built in decorators` like `@staticmethod`, `@classmethod`, `@abstractmethod` and `@property` etc
# - `User defined decorators` that we programmers can create according to our needs

# %%
#Python are first class functions
def modify(func,num):
    return func(num)

def square(num):
    return num**2

modify(square, 5)
# Out:
# 25

# %%
#simple example of decorator
def my_decorator(func):
    def wrapper():
        print('*******************')
        func()
        print('*******************')
    return wrapper

def hello():
    print("hello")
    
def display():
    print("welcome to python")
a=my_decorator(hello)
a()
b=my_decorator(display)
b()
# Out:
# *******************
# hello
# *******************
# *******************
# welcome to python
# *******************

# %%
def outer():
    a=5
    def inner():
        print(a)
    return inner
b=outer()
b()
# Out:
# 5

# %%
#better syntax for decorator
def my_decorator(func):
    def wrapper():
        print('*******************')
        func()
        print('*******************')
    return wrapper

@my_decorator
def hello():
    print("hello")
    
@my_decorator
def display():
    print("welcome to python")
hello()
display()
# Out:
# *******************
# hello
# *******************
# *******************
# welcome to python
# *******************

# %%
# meaningful decorator example
import time
def timer(func):
    def wrapper():
        start=time.time()
        func()
        print(f"Time taken to execute the {func.__name__} is {time.time()-start} seconds")
    return wrapper
@timer
def display():
    print("welcome to python")
    time.sleep(2)
@timer
def hello():
    print("hello")
    time.sleep(2)

hello()
display()
# Out:
# hello
# Time taken to execute the hello is 2.0006167888641357 seconds
# welcome to python
# Time taken to execute the display is 2.0005075931549072 seconds

# %%
def sanity_check(data_type):
    def outer_wrapper(func):
        def inner_wrapper(*args):
            if type(args[0])!=data_type:
                print(f"Invalid data type. Expected {data_type}")
            else:
                func(*args)
        return inner_wrapper
    return outer_wrapper

@sanity_check(int)
def square(num):
    print(num**2)
    
@sanity_check(str)
def greet(name):
    print(f"Hello {name}")  
    
greet("Sameer")
# Out:
# Hello Sameer
